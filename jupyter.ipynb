# %% [markdown]
# ## ULTIMAS ALTRACOES PARA IMPORTAR DADOS DO RU DRIVE

# %%
new_cols_name = {
    'Carimbo de data/hora':'data_publicacao',
    'REGISTRAR:': 'tipo_registro',
    'DATA:':'data_acao',
    'PROFISSIONAL:':'nome_profissional',
    'SETOR':'nome_setor',
    'MUNICÍPIO':'municipio_atendido',

    'AÇÃO REALIZADA:': '',
    '1.Apoio Técnico Presencial (ATP)': '',
    '1.1 - Nº de profissionais atendidos(ATP)': '',
    '1.2 - Descrição da Ação (ATP)': '',
    '2.Apoio Técnico Não Presencial (ATNP)': '',
    '2.1 - Nº de profissionais atendidos(ATNP)': '',
    '2.2 - Descrição da Ação (ATNP)': '',
    '3.Outras Ações': '',
    '3.1 - Nº de profissionais atendidos (Outras ações)': '',
    '3.2 - Descrição da Ação (Outras)': '',
    'Nome do responsável pelo registro': '',
    ## PARTICIPACAO EVENTOS
    'Setores': 'nome_setor',
    'DATA DA PARTICIPAÇÃO': '',
    'LOCAL': '',
    'ESPAÇO DE PARTICIPAÇÃO': '',
    'DESCRIÇÃO': '',
    'ENCAMINHAMENTOS': '',
    ## INSTANCIAS INTERSETORIAIS
    'ESPAÇO DE PARTICIPAÇÃO - INSTÂNCIAS DO SUAS': '',
    'ESPAÇO DE PARTICIPAÇÃO - INSTÂNCIAS INTERSETORIAIS': '',
    'Data de início': '',
    'Data de término': '',
    'Título do Evento': '',
    'Instituição Ofertante': '',
    'Característica do Evento': '',
    'Nome do Profissional': '',
    'Setor que atua': '',
    'Descrição do evento': '',
    'email': ''}

# %%
import pandas as pd
link_registros ='https://docs.google.com/spreadsheets/d/e/2PACX-1vSSSzbKEW5XI8PKTj9mueR1cGi_GlTeUOmWVYIm9-i-zbCoZpelscZv_YSj4MXVcf4kN-_VY0AFpNDm/pub?gid=1021085548&single=true&output=csv'
reg = pd.read_csv(link_registros)
# filtra apenas ACOES
reg = reg.loc[reg['REGISTRAR:']=='AÇÕES REALIZADAS']
df_acoes = reg[['Carimbo de data/hora','DATA:','PROFISSIONAL:','SETOR','MUNICÍPIO','AÇÃO REALIZADA:',
    '1.Apoio Técnico Presencial (ATP)','1.1 - Nº de profissionais atendidos(ATP)','1.2 - Descrição da Ação (ATP)',
    '2.Apoio Técnico Não Presencial (ATNP)','2.1 - Nº de profissionais atendidos(ATNP)','2.2 - Descrição da Ação (ATNP)',
    '3.Outras Ações','3.1 - Nº de profissionais atendidos (Outras ações)','3.2 - Descrição da Ação (Outras)','email'
    ]].copy()
### renomeia algumas colunas
df_acoes = df_acoes.rename(columns={
    'Carimbo de data/hora':'data_publicacao',
    'DATA:':'data_acao',
    'PROFISSIONAL:':'nome_profissional',
    'SETOR':'sector_name',
    'MUNICÍPIO':'municipio_atendido',
    'AÇÃO REALIZADA:':'acao_realizada',
    '1.Apoio Técnico Presencial (ATP)': 'Apoio Técnico Presencial (ATP)',
    '2.Apoio Técnico Não Presencial (ATNP)':'Apoio Técnico Não Presencial (ATNP)',
    '3.Outras Ações': 'Outras Ações'
    })

### Altera os valores da coluna acao_realizada
dic_acao_realizada = {'1.Apoio Técnico Presencial (ATP)': 'Apoio Técnico Presencial (ATP)',
'2.Apoio Técnico Não Presencial (ATNP)':'Apoio Técnico Não Presencial (ATNP)',
'3.Outras Ações': 'Outras Ações'}
df_acoes['acao_realizada'] = df_acoes['acao_realizada'].map(dic_acao_realizada)


## NOVA COLUNA 1 - Cria a coluna 'caracteristica_acao' que vai importar os valores de 3 colunas diferentes baseadas no tipo de apoio técnico
mask1 = (df_acoes['acao_realizada']=='Apoio Técnico Presencial (ATP)')
mask2 = (df_acoes['acao_realizada']=='Apoio Técnico Não Presencial (ATNP)')
mask3 = (df_acoes['acao_realizada']=='Outras Ações')
list_mask = [mask1,mask2,mask3]
list_col_use = ['Apoio Técnico Presencial (ATP)','Apoio Técnico Não Presencial (ATNP)','Outras Ações']
for mask, col in zip(list_mask,list_col_use):
    df_acoes.loc[mask, 'caracteristica_acao'] = df_acoes[col]

### NOVA COLUNA 2 - Cria a coluna 'descricao_acao' que vai importar os valores de 3 colunas diferentes baseadas no tipo de apoio técnico
mask1 = (df_acoes['acao_realizada']=='Apoio Técnico Presencial (ATP)')
mask2 = (df_acoes['acao_realizada']=='Apoio Técnico Não Presencial (ATNP)')
mask3 = (df_acoes['acao_realizada']=='Outras Ações')

list_mask = [mask1,mask2,mask3]
list_col_use = ['1.2 - Descrição da Ação (ATP)','2.2 - Descrição da Ação (ATNP)','3.2 - Descrição da Ação (Outras)']

for mask, col in zip(list_mask,list_col_use):
    df_acoes.loc[mask, 'descricao_acao'] = df_acoes[col]

# ### NOVA COLUNA 3 - Cria a coluna 'n_profissionais_atendidos' que vai importar os valores de 3 colunas diferentes baseadas no tipo de apoio técnico
mask1 = (df_acoes['acao_realizada']=='Apoio Técnico Presencial (ATP)')
mask2 = (df_acoes['acao_realizada']=='Apoio Técnico Não Presencial (ATNP)')
mask3 = (df_acoes['acao_realizada']=='Outras Ações')

list_mask = [mask1,mask2,mask3]
list_col_use = ['1.1 - Nº de profissionais atendidos(ATP)','2.1 - Nº de profissionais atendidos(ATNP)','3.1 - Nº de profissionais atendidos (Outras ações)']

for mask, col in zip(list_mask,list_col_use):
    df_acoes.loc[mask, 'n_profissionais_atendidos'] = df_acoes[col]


# cria coluna 'user_id' para ser usada no futuro
# df_acoes['user_id'] = ''
## finaliza a base e armazena na variavel 'data'
data = df_acoes[['email','nome_profissional','acao_realizada','caracteristica_acao','n_profissionais_atendidos','descricao_acao',
    'data_acao','data_publicacao','municipio_atendido']].copy()
    
data.caracteristica_acao = data.caracteristica_acao.fillna('vazio')
data.n_profissionais_atendidos   = data.n_profissionais_atendidos.fillna(0)

# data['data_acao'] = pd.to_datetime(data['data_acao'], format='%YYYY %MM %DD')


data
# Out:
#                                    email               nome_profissional  \
# 0        anapaulaxavier@setasc.mt.gov.br          Ana Paula Xavier Brito
# 1        anapaulaxavier@setasc.mt.gov.br          Ana Paula Xavier Brito
# 2        anapaulaxavier@setasc.mt.gov.br          Ana Paula Xavier Brito
# 3        anapaulaxavier@setasc.mt.gov.br          Ana Paula Xavier Brito
# 4        anapaulaxavier@setasc.mt.gov.br          Ana Paula Xavier Brito
# ...                                  ...                             ...
# 5538  marielzagoncalves@setasc.mt.gov.br              Marielza Gonçalves
# 5539  marielzagoncalves@setasc.mt.gov.br              Marielza Gonçalves
# 5540     cristianevital@setasc.mt.gov.br  Cristiane Costa Vital de Souza
# 5541         maysasouza@setasc.mt.gov.br             Maysa Souza Persona
# 5637      andreiasantos@setasc.mt.gov.br                Andréia Carvalho
#
#                            acao_realizada  \
# 0     Apoio Técnico Não Presencial (ATNP)
# 1     Apoio Técnico Não Presencial (ATNP)
# 2     Apoio Técnico Não Presencial (ATNP)
# 3     Apoio Técnico Não Presencial (ATNP)
# 4     Apoio Técnico Não Presencial (ATNP)
# ...                                   ...
# 5538  Apoio Técnico Não Presencial (ATNP)
# 5539  Apoio Técnico Não Presencial (ATNP)
# 5540  Apoio Técnico Não Presencial (ATNP)
# 5541  Apoio Técnico Não Presencial (ATNP)
# 5637       Apoio Técnico Presencial (ATP)
#
#                         caracteristica_acao  n_profissionais_atendidos  \
# 0          E-mails, telefonemas e mensagens                        1.0
# 1          E-mails, telefonemas e mensagens                        1.0
# 2          E-mails, telefonemas e mensagens                        1.0
# 3          E-mails, telefonemas e mensagens                        1.0
# 4          E-mails, telefonemas e mensagens                        1.0
# ...                                     ...                        ...
# 5538       E-mails, telefonemas e mensagens                        1.0
# 5539       E-mails, telefonemas e mensagens                       50.0
# 5540       E-mails, telefonemas e mensagens                        1.0
# 5541       E-mails, telefonemas e mensagens                        1.0
# 5637  Apoio técnico individualizado na SAAS                        2.0
#
#                                          descricao_acao   data_acao  \
# 0     Telefonema com orientação sobre motivos de can...  28/07/2022
# 1     Telefonema com orientação sobre como resgatar ...  28/07/2022
# 2     Email e telefonema com orientação sobre Termo ...  27/07/2022
# 3     Email com orientação sobre critérios e procedi...  27/07/2022
# 4      Email e telefonema sobre Termo de Adesão CAD PAB  27/07/2022
# ...                                                 ...         ...
# 5538  Supervisora Josiane: sistema e-pcf - cadastro ...  11/01/2022
# 5539  Mensagem aos supervisores do PCF confirmando p...  15/09/2020
# 5540  Orientação e envio de e-mail com o passo a pas...  18/08/2022
# 5541  Orientação sobre composição de equipe técnica ...  17/10/2022
# 5637  Orientação técnica sobre execução orçamentária...  14/12/2022
#
#           data_publicacao                municipio_atendido
# 0     03/08/2022 16:35:31                            Denise
# 1     03/08/2022 16:36:56                           Tapurah
# 2     03/08/2022 16:26:32                            Denise
# 3     03/08/2022 16:28:29                  Nova Monte Verde
# 4     03/08/2022 16:29:43                            Nobres
# ...                   ...                               ...
# 5538  03/11/2022 11:09:02                          Acorizal
# 5539  04/10/2022 12:26:28             **Grupo de municípios
# 5540  25/08/2022 17:42:30                            Cuiabá
# 5541  28/10/2022 14:31:08                     Alto Araguaia
# 5637  15/12/2022 08:36:57  Vila Bela da Santíssima Trindade
#
# [5421 rows x 9 columns]

# %%
# data = data.drop(columns=['email','nome_profissional','data_publicacao'])
# data['n_profissionais_atendidos'] = data['n_profissionais_atendidos'].astype(int)
data['data_acao'] = pd.to_datetime(data['data_acao'])

# %%
data.acao_realizada.value_counts()
# Out:
# Apoio Técnico Não Presencial (ATNP)    4747
# Outras Ações                            475
# Apoio Técnico Presencial (ATP)          199
# Name: acao_realizada, dtype: int64

# %%
pd.read_csv('users.csv')
# Out:
#          username                             full_name          first_name  \
# 0             Ana                Ana Paula Xavier Brito           Ana Paula
# 1          Andréa      Andréa Trevizan Segóvia da Silva     Andréa Trevizan
# 2         Andréia                      Andréia Carvalho    Andréia Carvalho
# 3         Antônia                      Antônia Angélica    Antônia Angélica
# 4       Aparecida               Aparecida Maria de Lima     Aparecida Maria
# 5          Ariane                Ariane Aparecida Baena    Ariane Aparecida
# 6          Bianca                        Bianca Hardman      Bianca Hardman
# 7           Carla  Carla Aparecida P. da S. B. de Souza     Carla Aparecida
# 8        Claudete                    Claudete Pio Teles        Claudete Pio
# 9       Cristiane        Cristiane Costa Vital de Souza     Cristiane Costa
# 10         Dayana                          Dayana Silva        Dayana Silva
# 11           Eric                  Eric Ivan dos Santos           Eric Ivan
# 12            Eva           Eva Anete Nogueira Domingos           Eva Anete
# 13         Evanda            Evanda Ferreira de A. Lima     Evanda Ferreira
# 14       Fernanda       Fernanda Stella de O. B. Borges     Fernanda Stella
# 15       Grazieli     Grazieli Patrícia Ribeiro de Lima   Grazieli Patrícia
# 16         Josana     Josana Maria de Andrade do Amaral        Josana Maria
# 17    JussaraDias                          Jussara Dias        Jussara Dias
# 18   JussaraGomes                         Jussara Gomes       Jussara Gomes
# 19        Klebson              Klebson Fonseca de Souza     Klebson Fonseca
# 20          Leicy        Leicy Lucas de Miranda Vitório         Leicy Lucas
# 21         Lenyze                   Lenyze Grecco Gomes       Lenyze Grecco
# 22        Lillian             Lillian Borges Passarelli      Lillian Borges
# 23        Luciana               Luciana Alves Rodrigues       Luciana Alves
# 24       Lucienne                 Lucienne Alves Correa      Lucienne Alves
# 25      Marenilza                       Marenilza Gomes     Marenilza Gomes
# 26       Marielza                    Marielza Gonçalves  Marielza Gonçalves
# 27       Marilise           Marilise Ana Deon Peterlini        Marilise Ana
# 28        Marimar             Marimar Aparecida Michels   Marimar Aparecida
# 29         Marina            Marina Inêz Belém Siqueira         Marina Inêz
# 30          Maysa                   Maysa Souza Persona         Maysa Souza
# 31       Nathalia    Nathalia Tassiane Rodrigues Tostes   Nathalia Tassiane
# 32         Pamela             Pamela de Carvalho Vieira             Pamela
# 33       Rafaella           Rafaella P. França de Paula           Rafaella
# 34       Roverson                        Roverson Costa           Roverson
# 35  RubiaCristina          Rubia Cristina Lima da Silva      Rubia Cristina
# 36    RubiaRegina            Rubia Regina M. de Santana        Rubia Regina
# 37         Sandra             Sandra Maria Alves Guirra        Sandra Maria
# 38         Sheila                 Sheila Mara Damasceno         Sheila Mara
# 39         Sidnea             Sidnea Martins de Menezes      Sidnea Martins
# 40    SimoneFelix                          Simone Félix        Simone Félix
# 41   SimoneGarcia                  Simone Garcia Santos       Simone Garcia
# 42            Sue    Sue Ellen Modesto R. de Figueiredo           Sue Ellen
# 43         Thayna                      Thayna Capstrano    Thayna Capstrano
# 44          Vanea              Vanea Conceição da Costa     Vanea Conceição
# 45        Waldete             Waldete Eliane de Almeida      Waldete Eliane
#
#                            last_name                               email  \
# 0             Paula Xavier Brito         anapaulaxavier@setasc.mt.gov.br
# 1       Trevizan Segóvia da Silva           andreasilva@setasc.mt.gov.br
# 2                     Carvalho            andreiasantos@setasc.mt.gov.br
# 3                     Angélica          antoniaoliveira@setasc.mt.gov.br
# 4                  Maria de Lima          aparecidalima@setasc.mt.gov.br
# 5               Aparecida Baena             arianebaena@setasc.mt.gov.br
# 6                      Hardman              biancaalves@setasc.mt.gov.br
# 7     Aparecida P. da S. B. de Souza         carlasouza@setasc.mt.gov.br
# 8                     Pio Teles           claudeteteles@setasc.mt.gov.br
# 9            Costa Vital de Souza        cristianevital@setasc.mt.gov.br
# 10                       Silva              dayanasilva@setasc.mt.gov.br
# 11               Ivan dos Santos              ericneves@setasc.mt.gov.br
# 12       Anete Nogueira Domingos            evadomingos@setasc.mt.gov.br
# 13            Ferreira de A. Lima          evandaarruda@setasc.mt.gov.br
# 14          Stella de O. B. Borges       fernandaborges@setasc.mt.gov.br
# 15       Patrícia Ribeiro de Lima          grazielilima@setasc.mt.gov.br
# 16      Maria de Andrade do Amaral         josanaamaral@setasc.mt.gov.br
# 17                        Dias              jussaradias@setasc.mt.gov.br
# 18                       Gomes            jussaramoraes@setasc.mt.gov.br
# 19              Fonseca de Souza           klebsonsouza@setasc.mt.gov.br
# 20       Lucas de Miranda Vitório          leicyvitorio@setasc.mt.gov.br
# 21                 Grecco Gomes             lenyzegomes@setasc.mt.gov.br
# 22            Borges Passarelli       lillianpassarelli@setasc.mt.gov.br
# 23              Alves Rodrigues        lucianarodrigues@setasc.mt.gov.br
# 24                 Alves Correa           luciennealves@setasc.mt.gov.br
# 25                       Gomes           marenilzagomes@setasc.mt.gov.br
# 26                   Gonçalves        marielzagoncalves@setasc.mt.gov.br
# 27            Ana Deon Peterlini      marilisepeterlini@setasc.mt.gov.br
# 28            Aparecida Michels          marimarmichels@setasc.mt.gov.br
# 29           Inêz Belém Siqueira         marinasiqueira@setasc.mt.gov.br
# 30                Souza Persona              maysasouza@setasc.mt.gov.br
# 31     Tassiane Rodrigues Tostes          nathaliasilva@setasc.mt.gov.br
# 32            de Carvalho Vieira           pamelavieira@setasc.mt.gov.br
# 33             P. França de Paula         rafaellapaula@setasc.mt.gov.br
# 34             Ferreira da Costa          roversoncosta@setasc.mt.gov.br
# 35         Cristina Lima da Silva            rubiasilva@setasc.mt.gov.br
# 36           Regina M. de Santana          rubiasantana@setasc.mt.gov.br
# 37            Maria Alves Guirra           sandraguirra@setasc.mt.gov.br
# 38               Mara Damasceno         sheilajulkovski@setasc.mt.gov.br
# 39            Martins de Menezes          sidneamenezes@setasc.mt.gov.br
# 40                       Félix              simonefelix@setasc.mt.gov.br
# 41                Garcia Santos            simonesantos@setasc.mt.gov.br
# 42  Ellen Modesto R. de Figueiredo        suefigueiredo@setasc.mt.gov.br
# 43                   Capstrano                   thayna@setasc.mt.gov.br
# 44            Conceição da Costa             vaneacosta@setasc.mt.gov.br
# 45             Eliane de Almeida         waldetedragoni@setasc.mt.gov.br
#
#                                           sector_name  password1  password2
# 0   Coordenadoria de Gestão do Cadastro Único dos ...  admadm123  admadm123
# 1   Coordenadoria de Proteção Social Especial de M...  admadm123  admadm123
# 2   Coordenadoria de Regulação e Gestão Financeira...  admadm123  admadm123
# 3       Coordenadoria de Vigilância Socioassistencial  admadm123  admadm123
# 4             Coordenadoria de Proteção Social Básica  admadm123  admadm123
# 5   Coordenadoria de Gestão de Benefícios Socioass...  admadm123  admadm123
# 6                 Coordenadoria de Gestão do Trabalho  admadm123  admadm123
# 7             Coordenadoria de Proteção Social Básica  admadm123  admadm123
# 8   Coordenadoria de Gestão do Cadastro Único dos ...  admadm123  admadm123
# 9   Coordenadoria de Gestão do Cadastro Único dos ...  admadm123  admadm123
# 10      Coordenadoria de Vigilância Socioassistencial  admadm123  admadm123
# 11                Coordenadoria de Gestão do Trabalho  admadm123  admadm123
# 12  Coordenadoria de Gestão de Programas e Projeto...  admadm123  admadm123
# 13            Coordenadoria de Proteção Social Básica  admadm123  admadm123
# 14  Coordenadoria de Proteção Social Especial de A...  admadm123  admadm123
# 15            Coordenadoria de Proteção Social Básica  admadm123  admadm123
# 16  Coordenadoria de Proteção Social Especial de M...  admadm123  admadm123
# 17      Coordenadoria de Vigilância Socioassistencial  admadm123  admadm123
# 18  Coordenadoria de Gestão de Benefícios Socioass...  admadm123  admadm123
# 19            Coordenadoria de Proteção Social Básica  admadm123  admadm123
# 20                                         SAAS - GAB  admadm123  admadm123
# 21  Coordenadoria de Regulação e Gestão Financeira...  admadm123  admadm123
# 22                Coordenadoria de Gestão do Trabalho  admadm123  admadm123
# 23  Coordenadoria de Gestão de Programas e Projeto...  admadm123  admadm123
# 24      Coordenadoria de Vigilância Socioassistencial  admadm123  admadm123
# 25            Coordenadoria de Proteção Social Básica  admadm123  admadm123
# 26  Coordenadoria de Gestão de Programas e Projeto...  admadm123  admadm123
# 27  Coordenadoria de Proteção Social Especial de M...  admadm123  admadm123
# 28  Coordenadoria de Gestão de Programas e Projeto...  admadm123  admadm123
# 29            Coordenadoria de Proteção Social Básica  admadm123  admadm123
# 30  Coordenadoria de Proteção Social Especial de A...  admadm123  admadm123
# 31      Coordenadoria de Vigilância Socioassistencial  admadm123  admadm123
# 32  Coordenadoria de Regulação e Gestão Financeira...  admadm123  admadm123
# 33  Coordenadoria de Proteção Social Especial de A...  admadm123  admadm123
# 34      Coordenadoria de Vigilância Socioassistencial  admadm123  admadm123
# 35  Coordenadoria de Gestão do Cadastro Único dos ...  admadm123  admadm123
# 36  Coordenadoria de Proteção Social Especial de A...  admadm123  admadm123
# 37  Coordenadoria de Gestão do Cadastro Único dos ...  admadm123  admadm123
# 38                Coordenadoria de Gestão do Trabalho  admadm123  admadm123
# 39  Coordenadoria de Proteção Social Especial de A...  admadm123  admadm123
# 40  Coordenadoria de Gestão de Programas e Projeto...  admadm123  admadm123
# 41  Coordenadoria de Gestão de Programas e Projeto...  admadm123  admadm123
# 42            Coordenadoria de Proteção Social Básica  admadm123  admadm123
# 43  Coordenadoria de Regulação e Gestão Financeira...  admadm123  admadm123
# 44  Coordenadoria de Proteção Social Especial de M...  admadm123  admadm123
# 45                Coordenadoria de Gestão do Trabalho  admadm123  admadm123

# %%
pd.to_datetime(data['data_acao'],errors='coerce', format='%Y-%m-%d')
# Out:
# 0      NaT
# 1      NaT
# 2      NaT
# 3      NaT
# 4      NaT
#         ..
# 5538   NaT
# 5539   NaT
# 5540   NaT
# 5541   NaT
# 5637   NaT
# Name: data_acao, Length: 5421, dtype: datetime64[ns]
